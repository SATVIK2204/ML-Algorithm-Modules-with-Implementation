# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=np.load('./data/knn_data.npy')

# %%
data
# Out:
# array([[-0.15927943, -0.50701912,  0.        ],
#        [-1.18468292,  4.85563998,  0.        ],
#        [ 1.14926519, -1.46098092,  0.        ],
#        ...,
#        [ 6.96781813,  3.38809847,  1.        ],
#        [ 4.64918846,  2.48781748,  1.        ],
#        [ 4.65828437,  1.99809686,  1.        ]])

# %%
#seperate the data into X and Y
X=data[:,:-1]
Y=data[:,-1]

# %%
# take a random test point and find to which class it belongs
test_point=np.array([2.5,-2])

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.scatter(test_point[0],test_point[1],c='red',marker='*')
plt.show()

# %%
from Knn_Module import KNN

# %%
knn=KNN()

# %%
knn.model(X,Y,test_point)
# Out:
# 0.0

# %% [markdown]
# ### Here we can clearly see from the graph that our test point belongs to class 0, and the result given by our KNN model is also the same
